# %%
pip install DALL-E
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting DALL-E
#   Downloading DALL_E-0.1-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.8/dist-packages (from DALL-E) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from DALL-E) (2.25.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.8/dist-packages (from DALL-E) (3.6.4)
# Collecting mypy
#   Downloading mypy-0.991-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 70.8 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from DALL-E) (1.13.0+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from DALL-E) (1.21.6)
# Collecting blobfile
#   Downloading blobfile-2.0.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 KB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from DALL-E) (0.14.0+cu116)
# Collecting urllib3~=1.25
#   Downloading urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock~=3.0 in /usr/local/lib/python3.8/dist-packages (from blobfile->DALL-E) (3.8.2)
# Collecting pycryptodomex~=3.8
#   Downloading pycryptodomex-3.16.0-cp35-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml~=4.9 in /usr/local/lib/python3.8/dist-packages (from blobfile->DALL-E) (4.9.2)
# Requirement already satisfied: typing-extensions>=3.10 in /usr/local/lib/python3.8/dist-packages (from mypy->DALL-E) (4.4.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from mypy->DALL-E) (2.0.1)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (9.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (22.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (1.15.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (1.11.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (57.4.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.8/dist-packages (from pytest->DALL-E) (1.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->DALL-E) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->DALL-E) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->DALL-E) (2022.12.7)
# Installing collected packages: mypy-extensions, urllib3, pycryptodomex, mypy, blobfile, DALL-E
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed DALL-E-0.1 blobfile-2.0.0 mypy-0.991 mypy-extensions-0.4.3 pycryptodomex-3.16.0 urllib3-1.26.13

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    'hakurei/waifu-diffusion',
    torch_dtype=torch.float32
).to('cuda')

prompt = "1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"
with autocast("cuda"):
    image = pipe(prompt, guidance_scale=6)["sample"][0]  
    
image.save("test.png")
# Out:
# Downloading:   0%|          | 0.00/577 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/518 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.89k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/341 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/620 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/460 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/819 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.46G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/601 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# The config attributes {'requires_safety_checker': True} were passed to StableDiffusionPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-7cf33e1223e6> in <module>
#       3 from diffusers import StableDiffusionPipeline
#       4
# ----> 5 pipe = StableDiffusionPipeline.from_pretrained(
#       6     'hakurei/waifu-diffusion',
#       7     torch_dtype=torch.float32
#
# /usr/local/lib/python3.8/dist-packages/diffusers/pipeline_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     455                         load_method_name = importable_classes[class_name][1]
#     456
# --> 457                 load_method = getattr(class_obj, load_method_name)
#     458
#     459                 loading_kwargs = {}
#
# TypeError: getattr(): attribute name must be string
